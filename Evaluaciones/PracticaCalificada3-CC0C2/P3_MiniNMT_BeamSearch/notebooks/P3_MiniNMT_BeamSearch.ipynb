# %% [markdown]
# # Traducción con encoder-decoder, greedy vs beam, length penalty
#
# > Rellena las celdas siguiendo el README del proyecto.

# %%
# Bootstrap reproducible
import os, random, numpy as np, torch
SEED = 0
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
